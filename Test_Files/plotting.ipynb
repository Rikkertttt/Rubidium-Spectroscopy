# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import scipy.stats as stats
from lmfit import models

# %%
df1 = pd.read_csv('Variable current over Magnet\ALL0003\F0003CH3.CSV', header=None, usecols=[3,4])
df2 = pd.read_csv('Variable current over Magnet\ALL0003\F0003CH4.CSV', header=None, usecols=[3,4])
df3 = pd.read_csv('Variable current over Magnet\ALL0003\F0003MTH.CSV', header=None, usecols=[3,4])

# %%
plt.plot(df1[3], df1[4], ".")
plt.plot(df2[3], df2[4], ".")
plt.plot(df3[3], df3[4], ".")
